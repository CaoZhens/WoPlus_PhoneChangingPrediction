# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load Data
url = 'http://s3.amazonaws.com/assets.datacamp.com/course/dasi/present.txt'
df = pd.read_table(url, sep=' ')
df = df.set_index('year')
# attention：set_index default inplace = False
print df.shape
print df.columns
# Out:
# (63, 2)
# Index([u'boys', u'girls'], dtype='object')

# %%
# plot method on Series
# df['boys']
df['boys'].plot()
plt.legend(loc='best')

# %%
# plot method on DataFrame
df.plot()

# %%
# comment: dataframe's plot is the same with n Series's plot
df.boys.plot(color='g')
df.girls.plot(color='b')
plt.legend(loc='best')

# %%
# default kind = 'line'
# you can use other kind parameters
df.iloc[0:10,:].plot(kind='bar')

# %%
df.iloc[0:10,:].plot(kind='barh')

# %%
df.iloc[0:10,:].plot(kind='bar', stacked=True)

# %%
# Curmulated bar
# df.sum(axis=1)
df.div(df.sum(axis=1), axis=0)[:10]
# Out:
#           boys     girls
# year
# 1940  0.513339  0.486661
# 1941  0.513138  0.486862
# 1942  0.514193  0.485807
# 1943  0.513800  0.486200
# 1944  0.513561  0.486439
# 1945  0.513475  0.486525
# 1946  0.514256  0.485744
# 1947  0.513488  0.486512
# 1948  0.513102  0.486898
# 1949  0.513088  0.486912

# %%
# Scatter
df.plot(x='boys', y='girls', kind='scatter')
